# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import glob, os
from datetime import datetime
import seaborn as sns

# %%
master = [[],[],[]] # 0-2017,1-2016,2-2015
c = 1

os.chdir("./GithubContributions")
for file in glob.glob("*.xlsx"):
    year17 = []
    year16 = []
    year15 = []
    data = pd.read_excel(file,sheetname='sheet1')
    data = data.drop_duplicates()
    dates = list(data['Date'])
    contributions = list(data['XContributions'])
    for i in range(len(dates)):
        if(dates[i][0:4]=='2017'):
            year17.append(int(contributions[i]))
        elif(dates[i][0:4]=='2016'):
            year16.append(int(contributions[i]))
        elif(dates[i][0:4]=='2015'):
            year15.append(int(contributions[i]))
    master[0].append(np.std(year17))
    master[1].append(np.std(year16))
    master[2].append(np.std(year15))
    print file + ' ' + str(c)
    c = c+1
# Out:
# swankjesse.xlsx 1
# bkeepers.xlsx 2
# yihui.xlsx 3
# ashleygwilliams.xlsx 4
# sferik.xlsx 5
# benjamn.xlsx 6
# webmozart.xlsx 7
# jamesmontemagno.xlsx 8
# robdodson.xlsx 9
# weierophinney.xlsx 10
# cvrebert.xlsx 11
# mrmrs.xlsx 12
# mbostock.xlsx 13
# pedrovgs.xlsx 14
# muan.xlsx 15
# numbbbbb.xlsx 16
# dsyer.xlsx 17
# Ocramius.xlsx 18
# steveklabnik.xlsx 19
# jedisct1.xlsx 20
# ericelliott.xlsx 21
# fabpot.xlsx 22
# leafo.xlsx 23
# dlew.xlsx 24
# kylef.xlsx 25
# chenglou.xlsx 26
# akrabat.xlsx 27
# afollestad.xlsx 28
# olivergierke.xlsx 29
# nixzhu.xlsx 30
# brentvatne.xlsx 31
# juliangruber.xlsx 32
# nvie.xlsx 33
# GrahamCampbell.xlsx 34
# chrisjenx.xlsx 35
# donnemartin.xlsx 36
# domenic.xlsx 37
# indragiek.xlsx 38
# QuincyLarson.xlsx 39
# pkrumins.xlsx 40
# ashfurrow.xlsx 41
# mathiasbynens.xlsx 42
# FezVrasta.xlsx 43
# grp.xlsx 44
# davidfowl.xlsx 45
# DataTables.xlsx 46
# rdegges.xlsx 47
# mli.xlsx 48
# ddollar.xlsx 49
# JakeWharton.xlsx 50
# gaearon.xlsx 51
# joshaber.xlsx 52
# ...

# %%
dims = (20,5)
fig, axs = plt.subplots(ncols=3,figsize=dims)
axs[0].set_title("2017")
axs[1].set_title("2016")
axs[2].set_title("2015")
    
Y = [[],[],[]]
for i in range(3):
    for j in range(len(master[i])):
        if(master[i][j]<=100):
            Y[i].append(master[i][j])
p1 = sns.distplot(Y[0],bins=15,kde=False,ax=axs[0])
p2 = sns.distplot(Y[1],bins=25,kde=False,ax=axs[1])
p3 = sns.distplot(Y[2],bins=25,kde=False,ax=axs[2])
p1.set(xlabel='Standard Deviation', ylabel='No. of users')
p2.set(xlabel='Standard Deviation', ylabel='No. of users')
p3.set(xlabel='Standard Deviation', ylabel='No. of users')
plt.show()

# %%
print "mean std dev for the year 2017 - " + str(np.mean(Y[0]))
print "mean std dev for the year 2016 - " + str(np.mean(Y[1]))
print "mean std dev for the year 2015 - " + str(np.mean(Y[2]))
# Out:
# mean std dev for the year 2017 - 8.39745659838
# mean std dev for the year 2016 - 10.56789747
# mean std dev for the year 2015 - 11.4517212813
