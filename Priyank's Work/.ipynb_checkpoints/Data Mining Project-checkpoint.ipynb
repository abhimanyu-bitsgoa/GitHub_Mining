# %%
import urllib2
from pandas import DataFrame
from bs4 import BeautifulSoup
import math
# quote_page = 'https://github.com/'+username
# page = urllib2.urlopen(quote_page)
# soup = BeautifulSoup(page, 'html.parser')

repoNumC=[]
starNumC=[]
followerNumC=[]
followingNumC=[]
orgNameC=[]
locationNameC=[]
mailIdC=[]
webUrlC=[]
orgListC=[]
bioC=[]
yearsActiveC=[]
pinnedRepoC=[]
repoLanguagesC=[]
forkedReposC=[]
usernameC=[]
repoNumG=25;

def getText(obj):
    if obj:
        return obj.text.strip()
    else:
        return "***"
def generateOverview(username):
    
    quote_page = 'https://github.com/'+username
    page = urllib2.urlopen(quote_page)
    soup = BeautifulSoup(page, 'html.parser')
    
    repoNum=soup.find('a',attrs={'href':'/'+username+'?tab=repositories'}).find('span')
    starNum=soup.find('a',attrs={'href':'/'+username+'?tab=stars'}).find('span')
    followerNum=soup.find('a',attrs={'href':'/'+username+'?tab=followers'}).find('span')
    followingNum=soup.find('a',attrs={'href':'/'+username+'?tab=following'}).find('span')

    orgName=soup.find('span',attrs={'class':'p-org'})
    if orgName:
        orgName=orgName.find('div')
    locationName=soup.find('span',attrs={'class':'p-label'})
    mailId=soup.find('svg',attrs={'class':'octicon octicon-mail'})
    webUrl=soup.find('a',attrs={'class':'u-url'})
    orgList=soup.find('div',attrs={'class':'border-top py-3 clearfix'})
    bio=soup.find('div',attrs={'class':'p-note user-profile-bio'})
    yearsActive=soup.find('ul',attrs={'class':'filter-list small'})
    pinnedRepo=soup.find('ol',attrs={'class':'pinned-repos-list  mb-4 js-pinned-repos-reorder-list'})
    
    global repoNumC
    global starNumC
    global followerNumC
    global followingNumC
    global orgNameC
    global locationNameC
    global mailIdC
    global webUrlC
    global orgListC
    global bioC
    global yearsActiveC
    global pinnedRepoC
    
    repoNumC.append(getText(repoNum))
    starNumC.append(getText(starNum))
    followerNumC.append(getText(followerNum))
    followingNumC.append(getText(followingNum))
    orgNameC.append(getText(orgName))
    locationNameC.append(getText(locationName))
#     webUrlC.append(getText(webUrl))
#     print getText(repoNum)
#     print getText(starNum)
#     print getText(followerNum)
#     print getText(followingNum)
#     print getText(orgName)
#     print getText(locationName)
#     print getText(webUrl)
    if webUrl:
        webUrlC.append(1)
    else:
        webUrlC.append(0)

    if mailId:
        mailIdC.append(1)
    else:
        mailIdC.append(0)

    if bio:
        bioC.append(1)
    else:
        bioC.append(0)

    if orgList:
        orgListC.append(len(orgList.findAll('a')))
    else:
        orgListC.append(0)
        
    if yearsActive:
        yearsActiveC.append(len(yearsActive.findAll('li')))
    else:
        yearsActiveC.append(0)
    
    if pinnedRepo:
        pinnedRepoC.append(len(pinnedRepo.findAll('li')))
    else:
        pinnedRepoC.append(0)                   

    global repoNumG
    if repoNum:
        repoNumG=int(repoNum.text.strip())



# generateOverview(username)

def generateRepo(username):
    repoLanguages={}
    forkedRepos=0
    global repoLanguagesC
    global forkedReposC
    global repoNumG
    for i in range(1,int(math.ceil(repoNumG)+1)):
        quote_page = 'https://github.com/'+username+'?page='+str(i)+'&tab=repositories'
        page = urllib2.urlopen(quote_page)
        soup = BeautifulSoup(page, 'html.parser')
        repoList=soup.find('ul',attrs={'data-filterable-for':'your-repos-filter'})
        if repoList:
            for repo in repoList.findAll('li'):
                if(repo.find('span',attrs={'class':'f6 text-gray mb-1'})):
                    forkedRepos=forkedRepos+1
                language=repo.find('span',attrs={'itemprop':'programmingLanguage'})
                if language:
                    language=language.text.strip()
                    if language in repoLanguages:
                        repoLanguages[language]=repoLanguages[language]+1
                    else:
                        repoLanguages[language]=1;

#     print repoLanguages
    langTuple=[]
    for key in repoLanguages:
        langTuple.append(key.encode("utf-8")+":"+str(repoLanguages[key]))
    repoLanguagesC.append(langTuple)
    forkedReposC.append(forkedRepos)
#     print forkedRepos

usernameData = [line.strip() for line in open("/home/aronzx/Desktop/users", 'r')]
numUser=1
for username in usernameData:
    global usernameC
    generateOverview(username)
    repoNumG=repoNumG/25.0;
    generateRepo(username)
    usernameC.append(username)
    print username + " " +str(numUser)
    numUser=numUser+1
    
    print "**********"

    
df=DataFrame({'Username':usernameC,'Repositories':repoNumC,'Forked':forkedReposC,'Starred':starNumC,
             'Followers':followerNumC,'Following':followingNumC,'Company':orgNameC,
             'Location':locationNameC,'MailID':mailIdC,'Website':webUrlC,
             'Bio':bioC,'Orgnisations':orgListC,'Years_Active':yearsActiveC,
             'Pinned_Repos':pinnedRepoC,'Languages':repoLanguagesC})

df = df[['Username','Repositories','Forked','Starred',
             'Followers','Following','Company',
             'Location','MailID','Website',
             'Bio','Orgnisations','Years_Active',
             'Pinned_Repos','Languages']]
print df
df.to_excel('GitHub_Data.xlsx', sheet_name='sheet1', index=False)
# Out:
# GrahamCampbell 1
# **********
# fabpot 2
# **********
# weierophinney 3
# **********
# rkh 4
# **********
#          Username Repositories  Forked Starred Followers Following  \
# 0  GrahamCampbell           25       5    1.1k      3.4k        69
# 1          fabpot           28      27      73      7.5k         0
# 2   weierophinney          230     183      87        2k         5
# 3             rkh          185     101    2.1k      1.9k       545
#
#                  Company              Location  MailID  Website  Bio  \
# 0  Cambridge Consultants    The United Kingdom       1        1    1
# 1             SensioLabs         San Francisco       1        1    0
# 2      Zend Technologies  Sioux Falls, SD, USA       1        1    1
# 3              Travis CI                Zurich       1        1    0
#
#    Orgnisations  Years_Active  Pinned_Repos  \
# 0            22             6             6
# 1             8            12             6
# 2             4            10             0
# 3            18            10             6
#
#                                            Languages
# 0           [Python:1, Java:2, PHP:21, JavaScript:1]
# 1  [C:1, Python:2, JavaScript:1, C++:1, Standard ...
# 2  [Shell:2, Python:1, JavaScript:12, CoffeeScrip...
# 3  [C:7, Shell:8, Java:2, Python:1, JavaScript:13...

# %%
import urllib2
from pandas import DataFrame
from bs4 import BeautifulSoup
import math
quote_page = 'https://gist.github.com/paulmillr/2657075'
page = urllib2.urlopen(quote_page)
soup = BeautifulSoup(page, 'html.parser')

table=soup.find('table',attrs={'cellspacing':'0'}).find('tbody')

for name in table.findAll('tr'):
    print name.findAll('td')[0].find('a').text.strip()
# Out:
# GrahamCampbell
# fabpot
# weierophinney
# rkh
# josh
# SamyPesse
# rstacruz
# tmm1
# michalbe
# andrew
# Ocramius
# c9s
# steipete
# feross
# afc163
# ornicar
# afollestad
# KrauseFx
# tmcw
# bevacqua
# mikermcneil
# taylorotwell
# phodal
# gdi2290
# benbalter
# dcramer
# HugoGiraudel
# mrmrs
# hadley
# alex
# mbostock
# atmos
# DataTables
# yyx990803
# kevinsawicki
# mdo
# jonathanong
# nvie
# JedWatson
# michaelklishin
# orta
# frsyuki
# steveklabnik
# josegonzalez
# josephmisiti
# nicolasgramlich
# zcbenz
# pippinsplugins
# robrix
# parkr
# paulcbetts
# jdalton
# markstory
# donnemartin
# dsyer
# mgechev
# radar
# JakeWharton
# jverkoey
# josevalim
# gaearon
# nixzhu
# kripken
# joshaber
# suissa
# geerlingguy
# stefanpenner
# springmeyer
# dlew
# EisenbergEffect
# numbbbbb
# vladikoff
# rafaelfranca
# paulmillr
# Raynos
# zenorocha
# Urigo
# remy
# overtrue
# eduardolundgren
# davidsonfellipe
# notwaldorf
# JaviSoto
# dominictarr
# substack
# ashfurrow
# kylef
# yiminghe
# soffes
# mattdesl
# willdurand
# jedisct1
# cvrebert
# soyjavi
# technoweenie
# brianleroux
# Seldaek
# barretlee
# rauchg
# mitsuhiko
# indutny
# CamDavidsonPilon
# sahat
# mafintosh
# kytrinyx
# staltz
# jeremy
# FezVrasta
# yihui
# fzaninotto
# ai
# jnunemaker
# jfrazelle
# liu21st
# zilongshanren
# Shougo
# soumith
# dougwilson
# tomchristie
# arunoda
# madskristensen
# mrdoob
# ericholscher
# pedrovgs
# kentcdodds
# mikepenz
# ashleygwilliams
# mathiasbynens
# bbatsov
# muan
# brentvatne
# mitchellh
# weaverryan
# jgm
# ddollar
# jakiestfu
# pkrumins
# mattn
# Unknwon
# ebidel
# samdark
# alloy
# jamesward
# indragiek
# tokuhirom
# schwa
# thomasdavis
# curran
# amasad
# torvalds
# drnic
# leafo
# rwaldron
# benjamn
# Caged
# jessesquires
# chjj
# mcollina
# mjackson
# swannodette
# tqchen
# simurai
# jlord
# domenic
# marijnh
# appleboy
# vhf
# sferik
# QuincyLarson
# prakhar1989
# angusshire
# nzakas
# kittens
# StephenGrider
# thejameskyle
# kriskowal
# kevva
# gorhill
# creationix
# hemanth
# ibdknox
# chenglou
# ChenYilong
# ericelliott
# Haacked
# ekmett
# davecheney
# kazuho
# rdegges
# shiffman
# tylermcginnis
# apotonick
# lihaoyi
# chrisjenx
# aaronpk
# evanw
# purcell
# leebyron
# agentzh
# jskeet
# samuelclay
# maxogden
# samccone
# swankjesse
# jamesmontemagno
# jiyinyiyong
# mourner
# drakeet
# wbond
# jennschiffer
# willianjusten
# tekkub
# kohsuke
# passy
# gitster
# stof
# ankane
# ericdouglas
# hueniverse
# olivergierke
# kishikawakatsumi
# balupton
# jamztang
# be5invis
# grp
# mjhea0
# ammeep
# kartik-v
# SamSaffron
# weavejester
# cyanogen
# AllenDowney
# mariotaku
# webmozart
# cheeaun
# sebastianbergmann
# addyosmani
# rasbt
# azat-co
# davidfowl
# fnando
# macournoyer
# robdodson
# toddmotto
# paulirish
# juliangruber
# bkeepers
# mli
# walkor
# zpao
# una
# tj
# johnpapa
# amueller
# AdamBien
# akrabat

# %%
import urllib2
from pandas import DataFrame
from bs4 import BeautifulSoup
import math
data = [line.strip() for line in open("/home/aronzx/Desktop/users", 'r')]
print data
# Out:
# ['GrahamCampbell', 'fabpot', 'weierophinney', 'rkh']
